# %% [markdown]
# # Project 3 - Behavioral Cloning

# %% [markdown]
# Import all modules.

# %%
import keras
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import csv
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.optimizers import SGD, Adam, RMSprop
from keras.utils import np_utils
from keras.layers import Convolution2D, MaxPooling2D
import json

print('Modules loaded successfully.')
# Out:
# Using TensorFlow backend.
# Modules loaded successfully.

# %% [markdown]
# ## Load all data (images + steering angle).

# %%
loadAllImages = 1

if loadAllImages == 1:
    
    # Training Data.
    imgfilenames = sorted(os.listdir('data/controller/training/IMG'))
    
    imgfilenamescenter = imgfilenames[0:6266] # Only images from the center camera are used.
    
    print(len(imgfilenamescenter)) 
    print('First image: ' + imgfilenamescenter[0] + '\nLast image: ' + imgfilenamescenter[-1])
    
    allimages = np.zeros([6266,160,320,3], dtype='uint8')
    
    i = -1
    for imgname in imgfilenamescenter:
        i += 1
        # Read in the image.
        
        imgfullname = 'data/controller/training/IMG/' + imgname
        allimages[i] = mpimg.imread(imgfullname)
        
    # Test Data.
    imgfilenames = sorted(os.listdir('data/controller/test/IMG'))
    
    imgfilenamescenter = imgfilenames[0:821] # Only images from the center camera are used.
    
    print(len(imgfilenamescenter)) 
    print('First image: ' + imgfilenamescenter[0] + '\nLast image: ' + imgfilenamescenter[-1])
    
    allimages_test = np.zeros([821,160,320,3], dtype='uint8')
    
    i = -1
    for imgname in imgfilenamescenter:
        i += 1
        # Read in the image.
        
        imgfullname = 'data/controller/test/IMG/' + imgname
        allimages_test[i] = mpimg.imread(imgfullname)
        
    print("All Images Loaded.")
# Out:
# 6266
# First image: center_2016_12_04_11_39_34_535.jpg
# Last image: center_2016_12_04_14_46_26_052.jpg
# 821
# First image: center_2016_12_04_11_54_37_548.jpg
# Last image: center_2016_12_04_11_56_02_501.jpg
# All Images Loaded.

# %%
loadAllSteering = 1

if loadAllSteering == 1:
    
    # Training Data.
    steeringdatafile = pd.read_csv('data/controller/training/driving_log.csv')
    allsteer = steeringdatafile['Steering'] #you can also use df['column_name']
    
    steername = steeringdatafile['Center']
    
    print(len(steername))
    print('First image: ' + steername[0] + '\nLast image: ' + steername[6265])
    
    steeringdatafile = None
    # Test Data.
    steeringdatafile = pd.read_csv('data/controller/test/driving_log.csv')
    allsteer_test = steeringdatafile['Steering'] #you can also use df['column_name']
    
    steername_test = steeringdatafile['Center']
    
    print(len(steername_test))
    print('First image: ' + steername_test[0] + '\nLast image: ' + steername_test[820])
    
    print('Steering Angle Loaded.')
# Out:
# 6266
# First image: C:\Users\Daniel\Downloads\simulator-windows-64\data\training\IMG\center_2016_12_04_11_39_34_535.jpg
# Last image: /home/daniel/SDC/Project-03/data/controller/training/IMG/center_2016_12_04_14_46_26_052.jpg
# 821
# First image: C:\Users\Daniel\Downloads\simulator-windows-64\data\test\IMG\center_2016_12_04_11_54_37_548.jpg
# Last image: C:\Users\Daniel\Downloads\simulator-windows-64\data\test\IMG\center_2016_12_04_11_56_02_501.jpg
# Steering Angle Loaded.

# %% [markdown]
# ## Verify collected data.

# %%
verify = 1

if verify == 1:

    testimage = 300

    print('Images: ' +str(len(allimages)) )
    print('Height: ' +str(len(allimages[0])) )
    print('Width: ' +str(len(allimages[0,0])) )
    print('Colors: ' +str(len(allimages[0,0,0])) )


    tempimg = mpimg.imread('data/controller/test/IMG/' + imgfilenamescenter[testimage])



    fig = plt.figure(figsize=(12, 4))
    figinfo = fig.add_subplot(1,2,1)
    plt.imshow(allimages_test[testimage,65:160])
    figinfo.set_title('allimages_test')

    figinfo=fig.add_subplot(1,2,2)
    plt.imshow(tempimg)
    figinfo.set_title('Direct')

    plt.show()

    print(allsteer[3])
# Out:
# Images: 6266
# Height: 160
# Width: 320
# Colors: 3
# -0.03773971

# %% [markdown]
# ## Prepare Data for Keras.

# %%
print('Data count of 32x32 color image: ' + str(32 * 32 *3) )
print('Data count of 160x320 color image: ' + str(160 * 320 *3) )
      
print('320x160 image is ' + str(160 * 320 *3 / (32*32*3)) +'x larger.' )
# Out:
# Data count of 32x32 color image: 3072
# Data count of 160x320 color image: 153600
# 320x160 image is 50.0x larger.

# %% [markdown]
# ### Normalize and Region of interest.
#
# Don't need top section of the image since I don't want the NN to memorize the track but rather learn how to corner based on the lines.

# %%
normalize = 1

def normalizeimg(image_data):
    a = -0.5
    b = 0.5
    max_val = 255
    min_val = 0
    
    norm_image_data = a + ( ( image_data - min_val)*(b - a)/(max_val - min_val) )
    
    return norm_image_data

if normalize == 1:
    X_train_norm = np.zeros( (len(allimages), 95, 320, 3), dtype='float32' )
    X_test_norm = np.zeros( (len(allimages_test), 95, 320, 3), dtype='float32' )
    
    for i in range( len(allimages) ):
        X_train_norm[i] = normalizeimg(allimages[i,65:160])
        
    for i in range( len(allimages_test) ):
        X_test_norm[i] = normalizeimg(allimages_test[i,65:160])
        
    print('All images normalized')
    

    print(X_train_norm[10,0,0,:])
    print(X_test_norm[10,0,0,:])
    
    print(len(X_train_norm[0]))
# Out:
# All images normalized
# [ 0.1509804  -0.0372549  -0.28823531]
# [ 0.13921569  0.24901961  0.33137256]
# 95

# %%
if loadAllSteering == 1:
    print(sum(allsteer)/(len(allsteer)))
    print(max(allsteer))
    print(min(allsteer))
    
    print('\n')
    
    print(sum(allsteer_test)/(len(allsteer_test)))
    print(max(allsteer_test))
    print(min(allsteer_test))
# Out:
# -0.012324440606
# 1.0
# -0.7639185
#
#
# -0.0344346374183
# 0.3307883
# -0.2876486

# %% [markdown]
# Since the steering angle data already has roughly a mean of zero and not very large max and min values I'm going to keep in as it is for now.

# %%
if normalize == 1:
    y_train = allsteer
    y_test = allsteer_test
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')
    print("Steering data done.")
# Out:
# Steering data done.

# %%
print(len(y_train))
print(len(y_test))
print(len(X_train_norm))
print(len(X_test_norm))
# Out:
# 6266
# 821
# 6266
# 821

# %% [markdown]
# ## Store data into pickle file.

# %%
pickle_file = 'preprocdata-5.pickle'
if not os.path.isfile(pickle_file):
    print('Saving data to pickle file...')
    try:
        with open('preprocdata-5.pickle', 'wb') as pfile:
            pickle.dump(
                {
                    'train_dataset': X_train_norm,
                    'train_output': y_train,
                    'test_dataset': X_test_norm,
                    'test_output': y_test,
                },
                pfile, pickle.HIGHEST_PROTOCOL)
    except Exception as e:
        print('Unable to save data to', pickle_file, ':', e)
        raise

print('Data cached in pickle file.')
# Out:
# Saving data to pickle file...
# Data cached in pickle file.

# %% [markdown]
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
#
# # Fresh Start Area

# %%
import keras
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import csv
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.optimizers import SGD, Adam, RMSprop
from keras.utils import np_utils
from keras.layers import Convolution2D, MaxPooling2D
import json
from scipy import signal

print('Modules loaded successfully.')
# Out:
# Using TensorFlow backend.
# Modules loaded successfully.

# %%
# Reload the data
pickle_file = 'preprocdata-5.pickle'
with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train_norm = pickle_data['train_dataset']
    y_train = pickle_data['train_output']
    X_test_norm = pickle_data['test_dataset']
    y_test = pickle_data['test_output']
    del pickle_data  # Free up memory

    
print('Data and modules loaded.')
# Out:
# Data and modules loaded.

# %%
print(X_train_norm[10,0,0,:])
print(y_train[3])

print(X_test_norm[10,0,0,:])
print(y_test[2])

print('Images: ' +str(len(X_train_norm)) )
print('Height: ' +str(len(X_train_norm[0])) )
print('Width: ' +str(len(X_train_norm[0,0])) )
print('Colors: ' +str(len(X_train_norm[0,0,0])) )

print(len(X_train_norm))
print(len(y_train))


print(len(X_test_norm))
print(len(y_test))


print(type(X_train_norm[0,0,0,0]))
print(type(y_train[0]))

print(type(X_test_norm[0,0,0,0]))
print(type(y_test[0]))


print('All input data verified.')
# Out:
# [ 0.1509804  -0.0372549  -0.28823531]
# -0.0377397
# [ 0.13921569  0.24901961  0.33137256]
# -0.00108037
# Images: 6266
# Height: 95
# Width: 320
# Colors: 3
# 6266
# 6266
# 821
# 821
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# All input data verified.

# %%
# User zero phase filter so that no phase shift occurs.

b, a = signal.butter(1, 1) # previously 0.1
y_train_zero = signal.filtfilt(b, a, y_train, padlen=20)

y_test_zero = signal.filtfilt(b, a, y_test, padlen=20)

y_train_zero = y_train_zero.astype('float32')
y_test_zero = y_test_zero.astype('float32')

print(type(y_test_zero[0]))
print(type(y_train_zero[0]))

fig = plt.figure(figsize=(12, 4))
figinfo = fig.add_subplot(1,2,1)
plt.plot(y_train[:],'b')
plt.plot(y_train_zero[:],'r')
figinfo.set_title('Train')
figinfo.set_xlim([5583,6266])
#figinfo.set_xlim([10,100])

figinfo=fig.add_subplot(1,2,2)
plt.plot(y_test)
plt.plot(y_test_zero,'r')
figinfo.set_title('Test')
plt.show()


#X_train_reshape = X_train_norm.reshape(len(X_train_norm), 153600)
#X_test_reshape = X_test_norm.reshape(len(X_test_norm), 153600)

X_train_final, X_valid_final, y_train_final, y_valid_final = train_test_split(
                                        X_train_norm, y_train_zero, test_size=0, random_state=1337)

plt.plot(y_train_final, 'r')
plt.show()

print(len(y_train_final))
# Out:
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# 6266

# %% [markdown]
# # Keras Convolution NN

# %%
# Create model.

# Convolution kernal size.
kernal_size = (3,3)

# Convolution filters
nb_filters = 12
pool_size = (2,2)
input_shape = (95,320,3)

model = Sequential()

# First convolution layer with max pooling and dropout.
model.add(Convolution2D(nb_filters*2, kernal_size[0]*2, kernal_size[1]*2,
                       border_mode = 'valid',
                       input_shape = input_shape))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.5))

# Second convolution layer with max pooling and dropout.
model.add(Convolution2D(nb_filters*3, kernal_size[0]*2, kernal_size[1]*2,
                       border_mode = 'valid',
                       input_shape = input_shape))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.5))

# Third convolution layer with max pooling and dropout.
model.add(Convolution2D(nb_filters*4, kernal_size[0], kernal_size[1],
                       border_mode = 'valid',
                       input_shape = input_shape))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.5))

# Fourth convolution layer with max pooling and dropout.
model.add(Convolution2D(64, kernal_size[0], kernal_size[1],
                       border_mode = 'valid',
                       input_shape = input_shape))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.5))

# fifth convolution layer with max pooling and dropout.
#model.add(Convolution2D(64, kernal_size[0], kernal_size[1],
#                       border_mode = 'valid',
#                       input_shape = input_shape))
#model.add(Activation('tanh'))
#model.add(MaxPooling2D(pool_size=pool_size))
#model.add(Dropout(0.5))

model.add(Flatten())

# First deep layer.
model.add(Dense(1024, input_shape=(153600,))) # 153600 = 160 x 320 x 3
model.add(Activation('tanh'))
model.add(Dropout(0.5))

# Second deep layer.
model.add(Dense(128))
model.add(Activation('linear'))
model.add(Dropout(0.5))

# Third deep layer.
model.add(Dense(64)) 
model.add(Activation('linear'))
model.add(Dropout(0.5))

# Fourth deep layer.
model.add(Dense(16)) 
model.add(Activation('linear'))
model.add(Dropout(0.5))

# Final output layer.
model.add(Dense(1))


model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_22 (Convolution2D) (None, 90, 315, 24)   2616        convolution2d_input_6[0][0]
# ____________________________________________________________________________________________________
# activation_38 (Activation)       (None, 90, 315, 24)   0           convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_22 (MaxPooling2D)   (None, 45, 157, 24)   0           activation_38[0][0]
# ____________________________________________________________________________________________________
# dropout_37 (Dropout)             (None, 45, 157, 24)   0           maxpooling2d_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D) (None, 40, 152, 36)   31140       dropout_37[0][0]
# ____________________________________________________________________________________________________
# activation_39 (Activation)       (None, 40, 152, 36)   0           convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_23 (MaxPooling2D)   (None, 20, 76, 36)    0           activation_39[0][0]
# ____________________________________________________________________________________________________
# dropout_38 (Dropout)             (None, 20, 76, 36)    0           maxpooling2d_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D) (None, 18, 74, 48)    15600       dropout_38[0][0]
# ____________________________________________________________________________________________________
# activation_40 (Activation)       (None, 18, 74, 48)    0           convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_24 (MaxPooling2D)   (None, 9, 37, 48)     0           activation_40[0][0]
# ____________________________________________________________________________________________________
# dropout_39 (Dropout)             (None, 9, 37, 48)     0           maxpooling2d_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D) (None, 7, 35, 64)     27712       dropout_39[0][0]
# ____________________________________________________________________________________________________
# activation_41 (Activation)       (None, 7, 35, 64)     0           convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_25 (MaxPooling2D)   (None, 3, 17, 64)     0           activation_41[0][0]
# ____________________________________________________________________________________________________
# dropout_40 (Dropout)             (None, 3, 17, 64)     0           maxpooling2d_25[0][0]
# ____________________________________________________________________________________________________
# flatten_5 (Flatten)              (None, 3264)          0           dropout_40[0][0]
# ____________________________________________________________________________________________________
# dense_21 (Dense)                 (None, 1024)          3343360     flatten_5[0][0]
# ____________________________________________________________________________________________________
# activation_42 (Activation)       (None, 1024)          0           dense_21[0][0]
# ____________________________________________________________________________________________________
# dropout_41 (Dropout)             (None, 1024)          0           activation_42[0][0]
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 128)           131200      dropout_41[0][0]
# ____________________________________________________________________________________________________
# activation_43 (Activation)       (None, 128)           0           dense_22[0][0]
# ____________________________________________________________________________________________________
# dropout_42 (Dropout)             (None, 128)           0           activation_43[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 64)            8256        dropout_42[0][0]
# ____________________________________________________________________________________________________
# activation_44 (Activation)       (None, 64)            0           dense_23[0][0]
# ____________________________________________________________________________________________________
# dropout_43 (Dropout)             (None, 64)            0           activation_44[0][0]
# ____________________________________________________________________________________________________
# dense_24 (Dense)                 (None, 16)            1040        dropout_43[0][0]
# ____________________________________________________________________________________________________
# activation_45 (Activation)       (None, 16)            0           dense_24[0][0]
# ____________________________________________________________________________________________________
# dropout_44 (Dropout)             (None, 16)            0           activation_45[0][0]
# ____________________________________________________________________________________________________
# dense_25 (Dense)                 (None, 1)             17          dropout_44[0][0]
# ====================================================================================================
# Total params: 3560941
# ____________________________________________________________________________________________________

# %%
nb_epoch = 30

batch_size = 50

model.compile(loss='mean_absolute_error', optimizer=Adam() )#optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True) )#metrics=['mean_squared_error'])

history = model.fit(X_train_norm[5583:6266], y_train_zero[5583:6266],
                    batch_size = batch_size, nb_epoch = nb_epoch,
                    verbose = 1, validation_split=0)

#history = model.fit(X_train_final, y_train_final,
#                    batch_size = batch_size, nb_epoch = nb_epoch,
#                    verbose = 1, validation_split=0.15)

print("Done.")
# Out:
# Epoch 1/30
# 683/683 [==============================] - 1s - loss: 0.2309
# Epoch 2/30
# 683/683 [==============================] - 0s - loss: 0.2147
# Epoch 3/30
# 683/683 [==============================] - 0s - loss: 0.2163
# Epoch 4/30
# 683/683 [==============================] - 0s - loss: 0.1906
# Epoch 5/30
# 683/683 [==============================] - 0s - loss: 0.1983
# Epoch 6/30
# 683/683 [==============================] - 0s - loss: 0.2036
# Epoch 7/30
# 683/683 [==============================] - 0s - loss: 0.1854
# Epoch 8/30
# 683/683 [==============================] - 0s - loss: 0.2042
# Epoch 9/30
# 683/683 [==============================] - 0s - loss: 0.1903
# Epoch 10/30
# 683/683 [==============================] - 0s - loss: 0.2089
# Epoch 11/30
# 683/683 [==============================] - 0s - loss: 0.1791
# Epoch 12/30
# 683/683 [==============================] - 0s - loss: 0.1849
# Epoch 13/30
# 683/683 [==============================] - 0s - loss: 0.1876
# Epoch 14/30
# 683/683 [==============================] - 1s - loss: 0.1825
# Epoch 15/30
# 683/683 [==============================] - 0s - loss: 0.1816
# Epoch 16/30
# 683/683 [==============================] - 1s - loss: 0.1740
# Epoch 17/30
# 683/683 [==============================] - 0s - loss: 0.1837
# Epoch 18/30
# 683/683 [==============================] - 0s - loss: 0.1820
# Epoch 19/30
# 683/683 [==============================] - 1s - loss: 0.1746
# Epoch 20/30
# 683/683 [==============================] - 1s - loss: 0.1717
# Epoch 21/30
# 683/683 [==============================] - 1s - loss: 0.1732
# Epoch 22/30
# 683/683 [==============================] - 0s - loss: 0.1894
# Epoch 23/30
# 683/683 [==============================] - 0s - loss: 0.1840
# Epoch 24/30
# 683/683 [==============================] - 1s - loss: 0.1696
# Epoch 25/30
# 683/683 [==============================] - 0s - loss: 0.1801
# Epoch 26/30
# 683/683 [==============================] - 0s - loss: 0.1733
# Epoch 27/30
# 683/683 [==============================] - 1s - loss: 0.1716
# Epoch 28/30
# 683/683 [==============================] - 0s - loss: 0.1742
# Epoch 29/30
# 683/683 [==============================] - 0s - loss: 0.1721
# Epoch 30/30
# 683/683 [==============================] - 0s - loss: 0.1711
# Done.

# %%
trainsteering = model.predict( X_train_norm, batch_size=100, verbose=1)
teststeering = model.predict( X_test_norm, batch_size=100, verbose=1)


fig = plt.figure(figsize=(12, 4))
figinfo = fig.add_subplot(1,2,1)
figinfo.set_title('Train')
plt.plot(y_train,'r--')
plt.plot(trainsteering,'k')
#figinfo.set_xlim([3000,5000]) # corner correct
figinfo.set_xlim([5583,6266]) # Hard right.


figinfo = fig.add_subplot(1,2,2)
plt.plot(teststeering,'k')
plt.plot(y_test,'r--')
figinfo.set_title('Test')
plt.show()
# Out:
# 6266/6266 [==============================] - 5s
# 821/821 [==============================] - 0s

# %%
score = model.evaluate(X_test_norm, y_test_zero, verbose=2)
print('Test Score:',score)
#print('Test Mean Absolute Error:', score[1])
# Out:
# Test Score: 0.021246608003

# %%
savemodel = 1

if savemodel == 1:
    model.save_weights('model.h5')
    model_json = model.to_json()
    #with open("model.json", "w") as json_file:
    #    json_file.write(model_json)
        
    with open('model.json', 'w') as f:
        json.dump(model_json, f)
        
    print("Architecture and weights saved.")
# Out:
# Architecture and weights saved.
